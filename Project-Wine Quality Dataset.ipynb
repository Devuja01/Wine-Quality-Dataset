# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Analyzation
#
#       These are the 12 attributes (features) and the output variable that describe a dataset related to wine quality. Each attribute represents a different characteristic of a wine, and the output variable "quality" represents the quality score of the wine, which is typically assigned by experts or sensory evaluation. Here's a brief definition of each attribute:
#
# Fixed Acidity: The amount of non-volatile acids in the wine, which contributes to the overall acidity.
#
# Volatile Acidity: The amount of volatile acids in the wine, which can have negative effects on taste and aroma if present in excessive amounts.
#
# Citric Acid: The amount of citric acid in the wine, which can add a fresh and citrus-like taste to the wine.
# Residual Sugar: The amount of sugar left in the wine after fermentation. It affects the sweetness of the wine.
#
# Chlorides: The amount of salt in the wine, which can influence the taste and overall balance.
#
# Free Sulfur Dioxide: The concentration of free sulfur dioxide in the wine, which helps to protect the wine from spoilage.
#
# Total Sulfur Dioxide: The total concentration of sulfur dioxide (both free and bound) in the wine. It's another measure of the wine's stability.
#
# Density: The density of the wine, which is related to the alcohol content and sweetness.
#
# pH: The pH level of the wine, which is an indicator of acidity.
#
# Sulphates: The concentration of sulfates in the wine, which can contribute to its aroma and flavor.
#
# Alcohol: The alcohol content of the wine, usually expressed as a percentage.
#
# Quality: The quality score assigned to the wine based on sensory evaluation, typically on a scale from 0 to 10, where higher scores indicate better quality.
#
#                     These attributes are often used as input features in machine learning models to predict or analyze the wine quality based on the given data. Researchers and wine experts may use such data to understand the factors that influence wine quality and to develop models for predicting or improving wine quality.

# %%
g=pd.read_csv('winequality-red.csv')
g
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
g.drop_duplicates(inplace=True)
g
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
sns.countplot(x='quality',data=g)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.scatterplot(y='pH',x='quality',data=g)

            #A "good quality" wine has an appropriate pH level that aligns with the intended style and characteristics of 
#that particular wine.
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sns.catplot(y='fixed acidity',x='quality',data=g)

# %%
sns.heatmap(g.corr(),cbar=True)
# Out:
# <Axes: >

# %%
x=g.iloc[:,0:11].values
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 5.9  ,  0.55 ,  0.1  , ...,  3.52 ,  0.76 , 11.2  ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
y=g.iloc[:,11].values
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=1/3,random_state=45)

# %%
x_train
# Out:
# array([[ 9.   ,  0.48 ,  0.32 , ...,  3.32 ,  0.62 ,  9.4  ],
#        [ 8.4  ,  0.715,  0.2  , ...,  3.31 ,  0.64 ,  9.4  ],
#        [ 7.5  ,  0.52 ,  0.16 , ...,  3.38 ,  0.62 ,  9.5  ],
#        ...,
#        [ 7.   ,  0.64 ,  0.02 , ...,  3.47 ,  0.67 ,  9.4  ],
#        [ 9.9  ,  0.35 ,  0.55 , ...,  3.26 ,  0.79 , 10.6  ],
#        [ 7.3  ,  0.4  ,  0.3  , ...,  3.41 ,  0.65 ,  9.5  ]])

# %%
x_test
# Out:
# array([[ 9.2 ,  0.56,  0.18, ...,  3.15,  0.49,  9.9 ],
#        [ 7.4 ,  0.36,  0.3 , ...,  3.24,  0.7 , 11.4 ],
#        [ 9.1 ,  0.6 ,  0.  , ...,  3.18,  0.63, 10.4 ],
#        ...,
#        [ 7.4 ,  0.52,  0.13, ...,  3.43,  0.59, 10.8 ],
#        [ 6.7 ,  0.76,  0.02, ...,  3.55,  0.63,  9.95],
#        [ 8.2 ,  0.23,  0.42, ...,  3.21,  0.54, 12.3 ]])

# %%
y_train
# Out:
# array([5, 5, 7, 5, 7, 6, 6, 7, 7, 6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6, 5, 7,
#        5, 5, 6, 6, 5, 5, 6, 5, 6, 7, 5, 7, 5, 5, 6, 6, 6, 4, 7, 6, 5, 7,
#        6, 5, 5, 5, 6, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5,
#        6, 6, 6, 5, 7, 5, 5, 7, 7, 7, 5, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6,
#        6, 6, 6, 7, 5, 6, 6, 7, 6, 5, 6, 5, 6, 7, 5, 6, 6, 5, 5, 5, 6, 5,
#        5, 5, 6, 5, 6, 6, 5, 6, 5, 6, 5, 4, 6, 6, 5, 4, 5, 6, 5, 6, 6, 6,
#        6, 4, 6, 6, 6, 5, 5, 5, 6, 5, 7, 6, 6, 6, 7, 8, 6, 5, 6, 6, 6, 6,
#        6, 6, 7, 6, 5, 6, 6, 7, 5, 6, 7, 5, 5, 5, 6, 4, 5, 6, 5, 7, 5, 5,
#        6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 7, 5, 6, 7, 5, 5, 5, 5,
#        7, 6, 5, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 6, 5, 5, 5, 5,
#        6, 5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 6, 7, 5, 6, 5, 7, 6, 7, 6, 5, 6,
#        5, 6, 4, 6, 7, 5, 5, 5, 5, 5, 6, 5, 6, 7, 7, 5, 8, 6, 4, 6, 6, 5,
#        6, 6, 6, 5, 5, 7, 5, 7, 5, 5, 6, 6, 6, 5, 5, 6, 6, 5, 5, 6, 5, 5,
# ...

# %%
y_test
# Out:
# array([5, 8, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 8, 5, 7, 7, 5, 5, 4, 5, 6, 6,
#        6, 6, 5, 5, 6, 6, 5, 6, 7, 7, 6, 5, 5, 6, 7, 6, 6, 5, 5, 5, 6, 6,
#        5, 5, 6, 5, 6, 7, 5, 5, 5, 7, 5, 5, 6, 7, 6, 5, 5, 5, 5, 6, 6, 7,
#        6, 4, 6, 7, 5, 5, 5, 7, 3, 5, 6, 5, 5, 6, 6, 5, 3, 6, 5, 4, 6, 6,
#        5, 6, 6, 5, 6, 6, 6, 5, 5, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 7, 7,
#        6, 6, 5, 5, 5, 6, 5, 6, 5, 6, 6, 5, 5, 6, 5, 3, 5, 7, 6, 6, 5, 6,
#        5, 6, 6, 5, 6, 6, 6, 6, 5, 6, 5, 6, 5, 7, 5, 5, 5, 5, 6, 6, 5, 5,
#        5, 6, 7, 6, 6, 5, 7, 6, 5, 8, 6, 7, 5, 6, 6, 5, 6, 5, 4, 5, 5, 7,
#        6, 6, 6, 5, 7, 6, 6, 5, 7, 5, 5, 5, 5, 6, 7, 5, 5, 7, 5, 7, 5, 7,
#        5, 6, 5, 5, 6, 5, 5, 5, 4, 5, 5, 5, 6, 6, 6, 7, 5, 5, 5, 5, 5, 6,
#        5, 5, 6, 6, 5, 5, 6, 6, 7, 5, 6, 5, 6, 6, 6, 4, 5, 6, 5, 6, 7, 8,
#        5, 5, 6, 5, 6, 7, 5, 4, 5, 7, 6, 6, 4, 6, 5, 6, 5, 6, 5, 6, 4, 6,
#        6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 8, 4, 5, 5, 5, 6, 6, 7, 5, 5, 6,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor= LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
xpred = regressor.predict(x_train)
xpred
# Out:
# array([5.13903834, 5.19223608, 5.38369955, 5.07653865, 6.16741868,
#        6.14687535, 5.74061582, 6.44899185, 6.08922822, 5.29054236,
#        4.98568984, 5.19154381, 5.52440312, 6.17387576, 4.83905838,
#        5.25294459, 5.22945099, 5.22776731, 5.17555081, 5.53907801,
#        5.20041897, 5.34537287, 5.63424252, 5.3262097 , 5.53127495,
#        5.55345546, 5.39242713, 5.49370195, 5.98814459, 5.45928311,
#        5.86562274, 6.27866197, 5.33973367, 6.18030073, 5.11124546,
#        4.25266481, 4.91400821, 5.48739833, 6.59987039, 5.14321569,
#        6.23881814, 6.14202805, 5.43701516, 5.85175308, 5.87235908,
#        5.05973951, 4.90619982, 5.39705422, 5.59214182, 6.18291551,
#        5.20791279, 5.63169962, 6.04867542, 5.0817607 , 5.20155209,
#        5.28185318, 5.21088614, 6.0647682 , 5.1537166 , 5.3321417 ,
#        5.68348198, 5.84799709, 5.5187303 , 5.07710231, 5.61729645,
#        5.29063661, 5.69105167, 6.19636383, 5.71866264, 5.66001797,
# ...

# %%
ypred = regressor.predict(x_test)
ypred
# Out:
# array([5.48953654, 6.30697979, 5.72757056, 5.65632976, 4.94766302,
#        6.345691  , 5.79530976, 5.23542334, 4.98263105, 5.15309289,
#        5.36698632, 5.54986197, 6.72396257, 6.61766387, 5.92637585,
#        6.90810568, 5.91285324, 5.88268263, 5.02514276, 5.71084455,
#        5.01225632, 5.66020999, 6.65549256, 5.28354271, 5.09246864,
#        5.50945616, 6.12206366, 5.70867037, 5.33928104, 6.28708169,
#        6.55420911, 6.32817215, 5.56555851, 5.15818765, 5.89173626,
#        5.82227352, 6.51938381, 5.08500427, 5.71909553, 5.78206816,
#        4.94950374, 5.61628608, 5.77269765, 5.94640528, 5.09740848,
#        5.61552808, 6.22639352, 5.595269  , 5.94957222, 6.42811466,
#        5.10323291, 5.49603863, 6.5867265 , 5.84464671, 6.30540395,
#        4.96523291, 5.59451483, 5.72525425, 6.31892588, 5.01756665,
#        5.40471709, 4.93848905, 5.23394499, 5.46520464, 5.76870004,
#        6.05271912, 6.13901577, 5.11718075, 6.48466253, 6.51724382,
# ...

# %%
score= regressor.score(x_train,y_train)
score
# Out:
# 0.3522212080584789

# %%
trainingscore= regressor.score(x_test,y_test)
trainingscore
# Out:
# 0.36977579161627794

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
g
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
fixedacidity =float(input('Enter the acidity:'))
volatileacidity =float(input('Enter the volatile:'))
citricacidity=float(input('Enter the : citricacidity'))
residualsugar=float(input('enter the sugarlevel'))
chlorides =float(input('Enter the chlorides:'))
freeSO2=float(input('Enter the SO2:'))
fullSO2=float(input('Enter the SO2:'))
density=float(input('Enter the density:'))
pH=float(input('Enter the pH'))
sulphates=float(input('Enter the sulphates'))
alcohol=float(input('Enter the alcohol'))



result=[fixedacidity,volatileacidity,citricacidity,residualsugar,chlorides,freeSO2,fullSO2,density,pH,sulphates,alcohol]
n=np.asarray(result)
newarray=n.reshape(1,-1)
pred=regressor.predict(newarray)
a=float(pred)
print('quality',a)
# Out:
# Enter the acidity:6
# Enter the volatile:0.310
# Enter the : citricacidity0.47
# enter the sugarlevel3.6
# Enter the chlorides:0.3472
# Enter the SO2:18
# Enter the SO2:42.0
# Enter the density:0.8342
# Enter the pH0.66
# Enter the sulphates11.0
# Enter the alcohol6
# quality 15.590687545874061

# %%
from sklearn.svm import SVR

# %%
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
xpred = svr.predict(x_train)
xpred
# Out:
# array([5.05254683, 5.10054837, 5.2615214 , 4.90810851, 6.25926365,
#        6.21943371, 5.63528891, 6.33473538, 6.22204735, 5.20220412,
#        4.92517916, 5.15035353, 5.42853472, 6.28616222, 4.8041932 ,
#        5.1209668 , 5.14887267, 5.24374073, 5.10630256, 5.6639922 ,
#        5.07460161, 5.2310241 , 5.63884832, 5.29961174, 5.40895728,
#        5.41368708, 5.27781223, 5.37152958, 5.97611915, 5.29885833,
#        5.67033192, 6.33291732, 5.28744283, 6.22130324, 5.07044802,
#        4.23027968, 4.89149087, 5.31300838, 6.65634031, 5.24400783,
#        6.44017554, 6.1010648 , 5.30622851, 5.69210213, 5.85419895,
#        4.9036107 , 4.98317492, 5.26428909, 5.50671656, 6.04973101,
#        5.28166348, 5.60764494, 5.92577182, 5.09692863, 5.254321  ,
#        5.16861616, 5.28467305, 6.07417832, 5.07284383, 5.25637679,
#        5.69963175, 5.87263835, 5.37822436, 5.05322176, 5.60446162,
#        5.13523447, 5.65405308, 6.20553244, 5.61424706, 5.57654043,
# ...

# %%
ypred = svr.predict(x_test)
ypred
# Out:
# array([5.37399925, 6.22023502, 5.64448039, 5.55646361, 4.83181808,
#        6.39302891, 5.66592659, 5.10437193, 4.90383916, 5.03806495,
#        5.21909414, 5.43254403, 6.85998946, 6.52565971, 5.84178936,
#        6.86734521, 5.8838493 , 5.90713349, 4.94829069, 5.59802299,
#        5.14922103, 5.66358071, 6.51167406, 5.28982567, 4.97405693,
#        5.40199715, 6.06296317, 5.69801179, 5.26211222, 6.15769471,
#        6.62120519, 6.39523706, 5.57343736, 5.07436112, 5.88666472,
#        5.68051701, 6.5350878 , 5.05566493, 5.64231611, 5.61095334,
#        4.96831056, 5.45524849, 5.72574468, 5.99366541, 4.92515426,
#        5.42319458, 6.11988801, 5.52036263, 5.9649816 , 6.31659711,
#        4.97020404, 5.41738579, 6.21375775, 5.9298007 , 6.31985237,
#        4.9199623 , 5.66430012, 5.76992524, 6.31217839, 4.94158269,
#        5.22607962, 4.84046845, 5.05336358, 5.42429124, 5.80247479,
#        6.14416423, 5.99922436, 5.32988682, 6.44281487, 6.53803983,
# ...

# %%
score= svr.score(x_train,y_train)
score
# Out:
# 0.3361606367617205

# %%
trainingscore= svr.score(x_test,y_test)
trainingscore
# Out:
# 0.38931089182564416
